# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import sklearn as sk
data=pd.read_csv("car data.csv")
data.tail(2)
from sklearn import linear_model

# %%
data1=data.drop(['Car_Name','Selling_Price','Owner','Seller_Type'],axis='columns')
data1.head(3)
# Out:
#    Year  Present_Price  Kms_Driven Fuel_Type Transmission
# 0  2014           5.59       27000    Petrol       Manual
# 1  2013           9.54       43000    Diesel       Manual
# 2  2017           9.85        6900    Petrol       Manual

# %%
target=data.Selling_Price
target.head(4)
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# Name: Selling_Price, dtype: float64

# %%
data1.head(2)
# Out:
#    Year  Present_Price  Kms_Driven Fuel_Type Transmission
# 0  2014           5.59       27000    Petrol       Manual
# 1  2013           9.54       43000    Diesel       Manual

# %%
data1.count()
# Out:
# Year             301
# Present_Price    301
# Kms_Driven       301
# Fuel_Type        301
# Transmission     301
# dtype: int64

# %%
numerics=LabelEncoder()
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data1['Fuel_Type_n']=numerics.fit_transform(data1['Fuel_Type'])
data1['Transmission_n']=numerics.fit_transform(data1['Transmission'])

# %%
data1
# Out:
#      Year  Present_Price  Kms_Driven Fuel_Type Transmission  Fuel_Type_n  \
# 0    2014           5.59       27000    Petrol       Manual            2
# 1    2013           9.54       43000    Diesel       Manual            1
# 2    2017           9.85        6900    Petrol       Manual            2
# 3    2011           4.15        5200    Petrol       Manual            2
# 4    2014           6.87       42450    Diesel       Manual            1
# ..    ...            ...         ...       ...          ...          ...
# 296  2016          11.60       33988    Diesel       Manual            1
# 297  2015           5.90       60000    Petrol       Manual            2
# 298  2009          11.00       87934    Petrol       Manual            2
# 299  2017          12.50        9000    Diesel       Manual            1
# 300  2016           5.90        5464    Petrol       Manual            2
#
#      Transmission_n
# 0                 1
# 1                 1
# 2                 1
# ...

# %%
data1=data1.drop(['Fuel_Type',"Transmission"],axis='columns')

# %%
data1.head(8)
# Out:
#    Year  Present_Price  Kms_Driven  Fuel_Type_n  Transmission_n
# 0  2014           5.59       27000            2               1
# 1  2013           9.54       43000            1               1
# 2  2017           9.85        6900            2               1
# 3  2011           4.15        5200            2               1
# 4  2014           6.87       42450            1               1
# 5  2018           9.83        2071            1               1
# 6  2015           8.12       18796            2               1
# 7  2015           8.61       33429            1               1

# %%
model=linear_model.LinearRegression()
model2=linear_model.LinearRegression()

# %%
model.fit(data1,target)
# Out:
# LinearRegression()

# %%
pred=model.predict([[2014,6.0,27000	,2,1]])
print(pred)
# Out:
# [3.5854688]

# %%
model.coef_
# Out:
# array([ 4.28634537e-01,  4.75947060e-01, -5.80569400e-06, -1.68082597e+00,
#        -1.20865018e+00])

# %%
model.intercept_
# Out:
# -857.8131152484626

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
import joblib as jb

# %%
jb.dump(model,'joblib_model')
# Out:
# ['joblib_model']

# %%
mj=jb.load("joblib_model")

# %%
mj.predict([[2014,6.0,27000,2,1]])
# Out:
# array([3.5854688])
